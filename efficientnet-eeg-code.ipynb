# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
    #for filename in filenames:
        #print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.utils import to_categorical
import pyarrow.parquet as pq
import io
from PIL import Image

# Define dataset directories
data_csv = "/kaggle/input/hms-harmful-brain-activity-classification/train.csv"
parquet_dir = "/kaggle/input/hms-harmful-brain-activity-classification/train_spectrograms"

# Load metadata
df = pd.read_csv(data_csv)

# Filter rows that have corresponding parquet files
existing_files = set(os.listdir(parquet_dir))
df = df[df["spectrogram_id"].apply(lambda x: f"{x}.parquet" in existing_files)]

# Limit to first 2000 samples for speed
df = df.head(5000)

# Encode labels
y = df["expert_consensus"].dropna()
df = df.loc[y.index]
le = LabelEncoder()
y_encoded = le.fit_transform(y)
y_categorical = to_categorical(y_encoded)

# Metadata features
X_meta = df[['seizure_vote', 'lpd_vote', 'gpd_vote', 'lrda_vote', 'grda_vote', 'other_vote']].values
scaler = StandardScaler()
X_meta = scaler.fit_transform(X_meta)

# Helper to convert spectrogram parquet to image array
def load_spectrogram_as_image(spectrogram_id, size=(224, 224)):
    file_path = os.path.join(parquet_dir, f"{spectrogram_id}.parquet")
    table = pq.read_table(file_path)
    data = table.to_pandas().values.T
    data = np.log1p(np.clip(data, a_min=1e-6, a_max=None))
    data = (data - np.min(data)) / (np.max(data) - np.min(data) + 1e-8)
    img = Image.fromarray(np.uint8(data * 255)).convert("RGB").resize(size)
    return np.array(img)

# Load spectrogram images
X_images = np.stack([load_spectrogram_as_image(sid) for sid in df["spectrogram_id"]])
X_images = X_images / 255.0

# Split dataset
X_img_train, X_img_temp, X_meta_train, X_meta_temp, y_train, y_temp = train_test_split(
    X_images, X_meta, y_categorical, test_size=0.3, random_state=42, stratify=y_categorical)
X_img_val, X_img_test, X_meta_val, X_meta_test, y_val, y_test = train_test_split(
    X_img_temp, X_meta_temp, y_temp, test_size=0.5, random_state=42, stratify=y_temp)

# EfficientNet model
base_model = keras.applications.EfficientNetB0(include_top=False, input_shape=(224, 224, 3), weights='imagenet')
base_model.trainable = True

image_input = keras.Input(shape=(224, 224, 3), name="image_input")
x = base_model(image_input, training=True)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.5)(x)
image_features = layers.Dense(128, activation='relu')(x)

# Metadata model
meta_input = keras.Input(shape=(X_meta.shape[1],), name="meta_input")
y_meta = layers.Dense(64, activation='relu')(meta_input)
y_meta = layers.Dropout(0.3)(y_meta)
meta_features = layers.Dense(32, activation='relu')(y_meta)

# Merge models
merged = layers.concatenate([image_features, meta_features])
z = layers.Dense(128, activation='relu')(merged)
z = layers.Dropout(0.5)(z)
out = layers.Dense(y_categorical.shape[1], activation='softmax')(z)

# Final model
model = keras.Model(inputs=[image_input, meta_input], outputs=out)

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Train model
history = model.fit(
    x=[X_img_train, X_meta_train],
    y=y_train,
    epochs=10,
    batch_size=32,
    validation_data=([X_img_val, X_meta_val], y_val)
)

# Evaluate model
y_pred = model.predict([X_img_test, X_meta_test])
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)

print("Test Accuracy:", accuracy_score(y_true_classes, y_pred_classes))
print("Classification Report:\n", classification_report(y_true_classes, y_pred_classes))

# Confusion Matrix
plt.figure(figsize=(6, 4))
plt.imshow(confusion_matrix(y_true_classes, y_pred_classes), cmap='Blues', interpolation='nearest')
plt.colorbar()
plt.title("Confusion Matrix - Test Set")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
# 2025-04-27 15:37:21.913450: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745768242.109688      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745768242.163763      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /tmp/ipykernel_31/3325694890.py:47: RuntimeWarning: invalid value encountered in log1p
#   data = np.log1p(np.clip(data, a_min=1e-6, a_max=None))
# /tmp/ipykernel_31/3325694890.py:49: RuntimeWarning: invalid value encountered in cast
#   img = Image.fromarray(np.uint8(data * 255)).convert("RGB").resize(size)
# I0000 00:00:1745768430.623291      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1745768492.120509      80 service.cc:148] XLA service 0x79877c002130 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1745768492.121132      80 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1745768497.044501      80 cuda_dnn.cc:529] Loaded cuDNN version 90300
# E0000 00:00:1745768505.847629      80 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1745768506.033157      80 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1745768506.494851      80 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1745768506.701037      80 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1745768507.056053      80 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1745768507.261879      80 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1745768526.867961      80 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 109/110 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.3382 - loss: 1.6169
# E0000 00:00:1745768549.537632      80 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1745768549.722129      80 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1745768550.142251      80 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1745768550.346815      80 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1745768550.689168      80 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1745768550.893626      80 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 144s 512ms/step - accuracy: 0.3397 - loss: 1.6143 - val_accuracy: 0.5440 - val_loss: 1.6649
# Epoch 2/10
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 13s 115ms/step - accuracy: 0.5948 - loss: 1.1127 - val_accuracy: 0.6973 - val_loss: 1.5915
# Epoch 3/10
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 13s 115ms/step - accuracy: 0.7404 - loss: 0.7711 - val_accuracy: 0.4947 - val_loss: 1.4625
# Epoch 4/10
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 13s 115ms/step - accuracy: 0.8110 - loss: 0.6124 - val_accuracy: 0.7240 - val_loss: 1.3521
# Epoch 5/10
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 13s 115ms/step - accuracy: 0.8732 - loss: 0.4485 - val_accuracy: 0.7120 - val_loss: 1.2132
# Epoch 6/10
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 13s 115ms/step - accuracy: 0.9107 - loss: 0.3320 - val_accuracy: 0.6920 - val_loss: 1.1178
# Epoch 7/10
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 13s 115ms/step - accuracy: 0.9218 - loss: 0.3034 - val_accuracy: 0.7773 - val_loss: 0.7698
# Epoch 8/10
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 13s 115ms/step - accuracy: 0.9317 - loss: 0.2505 - val_accuracy: 0.8547 - val_loss: 0.4616
# Epoch 9/10
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 13s 115ms/step - accuracy: 0.9461 - loss: 0.2124 - val_accuracy: 0.9613 - val_loss: 0.1651
# Epoch 10/10
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 13s 116ms/step - accuracy: 0.9551 - loss: 0.1753 - val_accuracy: 0.9653 - val_loss: 0.1344
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 14s 295ms/step
# Test Accuracy: 0.952
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96       188
#            1       0.99      0.95      0.97       148
#            2       0.94      0.97      0.95        96
#            3       0.99      0.95      0.97       121
#            4       0.93      0.84      0.88        85
#            5       0.91      0.96      0.94       112
#
#     accuracy                           0.95       750
#    macro avg       0.95      0.94      0.95       750
# weighted avg       0.95      0.95      0.95       750
